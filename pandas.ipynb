# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Avinash\Desktop\newfile.csv")

# %%
data.head()
# Out:
#       a         b         c         d  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0 -55.0  0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 1 -51.4  0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 2 -47.8  0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 3 -44.2  0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 4 -40.6  0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 321  Unnamed: 322  \
# 0    0.000013    0.000012    0.000012  ...      0.000009      0.000009
# 1    0.000013    0.000012    0.000012  ...      0.000009      0.000009
# 2    0.000013    0.000012    0.000012  ...      0.000009      0.000009
# 3    0.000013    0.000012    0.000012  ...      0.000009      0.000009
# 4    0.000013    0.000012    0.000012  ...      0.000009      0.000009
#
#    Unnamed: 323  Unnamed: 324  Unnamed: 325  Unnamed: 326  Unnamed: 327  \
# ...

# %%
X = data.iloc[: , 1:]

# %%
print(X)
# Out:
#            b         c         d  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 1   0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 2   0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 3   0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 4   0.000015  0.000015  0.000014    0.000014    0.000013    0.000013
# 5   0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 6   0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 7   0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 8   0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 9   0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 10  0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 11  0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# 12  0.000015  0.000015  0.000014    0.000014    0.000014    0.000013
# ...

# %%
y = pd.Series(X.values.ravel('F'))

# %%
y.to_csv('cref1.csv')

# %%
print(y)
# Out:
# 0        0.000015
# 1        0.000015
# 2        0.000015
# 3        0.000015
# 4        0.000015
#            ...
# 16825    0.000008
# 16826    0.000008
# 16827    0.000008
# 16828    0.000008
# 16829    0.000008
# Length: 16830, dtype: float64

# %%
t = data.iloc[:,0:1]

# %%
print(t)
print(data.columns)
# Out:
#         a
# 0   -55.0
# 1   -51.4
# 2   -47.8
# 3   -44.2
# 4   -40.6
# 5   -37.0
# 6   -33.4
# 7   -29.8
# 8   -26.2
# 9   -22.6
# 10  -19.0
# 11  -15.4
# 12  -11.8
# 13   -8.2
# 14   -4.6
# 15   -1.0
# 16    2.6
# 17    6.2
# 18    9.8
# 19   13.4
# 20   17.0
# 21   20.6
# 22   24.2
# 23   27.8
# 24   31.4
# 25   35.0
# 26   38.6
# 27   42.2
# 28   45.8
# 29   49.4
# 30   53.0
# 31   56.6
# 32   60.2
# 33   63.8
# 34   67.4
# 35   71.0
# 36   74.6
# 37   78.2
# 38   81.8
# 39   85.4
# 40   89.0
# 41   92.6
# 42   96.2
# 43   99.8
# 44  103.4
# 45  107.0
# 46  110.6
# 47  114.2
# 48  117.8
# 49  121.4
# 50  125.0
# Index(['a', 'b', 'c', 'd', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 321', 'Unnamed: 322', 'Unnamed: 323', 'Unnamed: 324',
#        'Unnamed: 325', 'Unnamed: 326', 'Unnamed: 327', 'Unnamed: 328',
#        'Unnamed: 329', 'Unnamed: 330'],
#       dtype='object', length=331)

# %%
dataset = pd.read_csv("test_final.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-92bded84eb19> in <module>
# ----> 1 dataset = pd.read_csv("test_final.csv")
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
len(dataset.iloc[: , 0:1])
# Out:
# 16830

# %%
dataset.head()
# Out:
#    Unnamed: 0         0
# 0           0  0.000015
# 1           1  0.000015
# 2           2  0.000015
# 3           3  0.000015
# 4           4  0.000015

# %%
len(dataset)
# Out:
# 16830

# %%
x1 = 1
for i in range(0,len(dataset),1581):
    dataset.iloc[i:i+1581,4:] = x1
    x1+=0.2
print(dataset)
dataset.to_csv("test_final.csv")
# Out:
#        Unnamed: 0         0      1    2    4    K
# 0               0  0.000015  -55.0  1.1  1.0  1.0
# 1               1  0.000015  -51.4  1.1  1.0  1.0
# 2               2  0.000015  -47.8  1.1  1.0  1.0
# 3               3  0.000015  -44.2  1.1  1.0  1.0
# 4               4  0.000015  -40.6  1.1  1.0  1.0
# ...           ...       ...    ...  ...  ...  ...
# 16825       16825  0.000008  110.6  1.1  3.0  3.0
# 16826       16826  0.000008  114.2  1.1  3.0  3.0
# 16827       16827  0.000008  117.8  1.1  3.0  3.0
# 16828       16828  0.000008  121.4  1.1  3.0  3.0
# 16829       16829  0.000008  125.0  1.1  3.0  3.0
#
# [16830 rows x 6 columns]

# %%
dataset["K"].head(51)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    1.0
# 21    1.0
# 22    1.0
# 23    1.0
# 24    1.0
# 25    1.0
# 26    1.0
# 27    1.0
# 28    1.0
# 29    1.0
# 30    1.0
# 31    1.0
# 32    1.0
# 33    1.0
# 34    1.0
# 35    1.0
# 36    1.0
# 37    1.0
# 38    1.0
# 39    1.0
# 40    1.0
# 41    1.0
# 42    1.0
# 43    1.0
# 44    1.0
# 45    1.0
# 46    1.0
# 47    1.0
# 48    1.0
# 49    1.0
# 50    1.0
# Name: K, dtype: float64

# %%
x1 = 33000
while(x1<=63000):
    for i in range(0,len(dataset),51):
        dataset.iloc[i:i+51,5:] = x1
        x1+=1000
    print(dataset)
#dataset.to_csv("test_final.csv")
# Out:
#        Unnamed: 0         0
# 0               0  0.000015
# 1               1  0.000015
# 2               2  0.000015
# 3               3  0.000015
# 4               4  0.000015
# ...           ...       ...
# 16825       16825  0.000008
# 16826       16826  0.000008
# 16827       16827  0.000008
# 16828       16828  0.000008
# 16829       16829  0.000008
#
# [16830 rows x 2 columns]

# %%
dataset1 = pd.read_csv(r"C:\Users\Avinash\test_final.csv")
# !pip install goto-statement

# %%
x1 = 33000
for i in range(0,len(dataset1),51):
    dataset1.iloc[i:i+51,5:] = x1
    x1+=1000
    if x1==64000:
        x1=33000
        continue
print(dataset1)
dataset1.to_csv("test_final_final_final.csv")
# Out:
#        Unnamed: 0      X         Y      Z    K        T
# 0               0      0  0.000015  -55.0  1.0  33000.0
# 1               1      1  0.000015  -51.4  1.0  33000.0
# 2               2      2  0.000015  -47.8  1.0  33000.0
# 3               3      3  0.000015  -44.2  1.0  33000.0
# 4               4      4  0.000015  -40.6  1.0  33000.0
# ...           ...    ...       ...    ...  ...      ...
# 16825       16825  16825  0.000008  110.6  3.0  52000.0
# 16826       16826  16826  0.000008  114.2  3.0  52000.0
# 16827       16827  16827  0.000008  117.8  3.0  52000.0
# 16828       16828  16828  0.000008  121.4  3.0  52000.0
# 16829       16829  16829  0.000008  125.0  3.0  52000.0
#
# [16830 rows x 6 columns]

# %%
dataset1.tail(60)
# Out:
#        Unnamed: 0      X         Y      Z    K        T
# 16770       16770  16770  0.000008   96.2  3.0  61000.0
# 16771       16771  16771  0.000008   99.8  3.0  61000.0
# 16772       16772  16772  0.000008  103.4  3.0  61000.0
# 16773       16773  16773  0.000008  107.0  3.0  61000.0
# 16774       16774  16774  0.000008  110.6  3.0  61000.0
# 16775       16775  16775  0.000008  114.2  3.0  61000.0
# 16776       16776  16776  0.000008  117.8  3.0  61000.0
# 16777       16777  16777  0.000008  121.4  3.0  61000.0
# 16778       16778  16778  0.000008  125.0  3.0  61000.0
# 16779       16779  16779  0.000008  -55.0  3.0  62000.0
# 16780       16780  16780  0.000008  -51.4  3.0  62000.0
# 16781       16781  16781  0.000008  -47.8  3.0  62000.0
# 16782       16782  16782  0.000008  -44.2  3.0  62000.0
# 16783       16783  16783  0.000008  -40.6  3.0  62000.0
# 16784       16784  16784  0.000008  -37.0  3.0  62000.0
# 16785       16785  16785  0.000008  -33.4  3.0  62000.0
# ...

# %%
for k in range(12):
    x1 = 33000
    for i in range(32):
        for j in range(52):
            dataset1.iloc[j,5:] = x1
        x1+=1000
print(dataset1)
# Out:
#        Unnamed: 0      X         Y      Z    K        T
# 0               0      0  0.000015  -55.0  1.0  64000.0
# 1               1      1  0.000015  -51.4  1.0  64000.0
# 2               2      2  0.000015  -47.8  1.0  64000.0
# 3               3      3  0.000015  -44.2  1.0  64000.0
# 4               4      4  0.000015  -40.6  1.0  64000.0
# ...           ...    ...       ...    ...  ...      ...
# 16825       16825  16825  0.000008  110.6  3.0  52000.0
# 16826       16826  16826  0.000008  114.2  3.0  52000.0
# 16827       16827  16827  0.000008  117.8  3.0  52000.0
# 16828       16828  16828  0.000008  121.4  3.0  52000.0
# 16829       16829  16829  0.000008  125.0  3.0  52000.0
#
# [16830 rows x 6 columns]
